# %%
# Main script to generate all the analysis figures in the manuscript "Observations of intermittent cross-shore bed load transport on a low-energy beach"

import os
import sys
import glob

import xarray as xr 
import numpy as np 
import pandas as pd
import scipy as sc
from scipy.signal import find_peaks

import matplotlib.pyplot as plt 
import matplotlib.colors as colors
import matplotlib.lines as mlines
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

sys.path.append(r'c:\checkouts\python\EURECCA\SEDRIB\analysis')
import puv
import xrMethodAccessors
from local_functions import *

plotFilePath = r'c:\checkouts\my\plotting\path'

if not os.path.exists(plotFilePath):
    os.mkdir(plotFilePath)

fold = r'c:\checkouts\DataCiaran'

# %%
d50 = 630e-6
g=9.8
rho_s=2650
rho_w=1025
nu=1e-6
n = 1.65

theta_crit = critical_shields(d50, delta=(rho_s-rho_w)/rho_w, nu=nu, g=g, method='soulsby_whitehouse97')

# %%
# load model grid for plotting
zz = np.loadtxt(os.path.join(fold, 'profile', 'z.txt'))
zz1 = np.loadtxt(os.path.join(fold, 'profile', 'z1.txt'))
zz2 = np.loadtxt(os.path.join(fold, 'profile', 'z2.txt'))
zz3 = np.loadtxt(os.path.join(fold, 'profile', 'z3.txt'))
xx = np.loadtxt(os.path.join(fold, 'profile', 'x.txt'))
yy = np.loadtxt(os.path.join(fold, 'profile', 'y.txt'))
dd = np.loadtxt(os.path.join(fold, 'profile', 'd.txt'))-188.5
dd1 = np.loadtxt(os.path.join(fold, 'profile', 'dd1.txt'))

# %%
##############
#%% FIGURE 2
##############
fig, ax = plt.subplots(2, 1, figsize=(4,4), height_ratios=[1, 2])
fig.subplots_adjust(hspace=0.3)
ax[0].plot(dd1, zz1, c='k')
ax[0].set_ylabel('z [m+NAP]')
ax[0].axis([-200, 70, -15, 5])
ax[0].set_yticks([-15, -5, 5])
ax[1].plot(dd, zz, c='k', label='11-01 17:00')
ax[1].plot(dd, zz2, c='r', label='11-03 16:00')
ax[1].plot(dd, zz3, c='g', label='11-08 09:00')
# tax = ax[1].twinx()
# tax.plot(dd, zz2-zz, c='c')
ax[1].legend(loc='upper left')
ax[1].axis([-15, 40, -2.5, 3])
ax[1].set_yticks([-2, 0, 2])
ax[1].set_xlabel('x [m]')
ax[1].set_ylabel('z [m+NAP]')
ax[1].grid(linewidth=0.5, color='grey', linestyle=':')
ax[1].axvline(0, color='C0', linestyle='--', linewidth=1)
ax[0].indicate_inset_zoom(ax[1], edgecolor="grey")

import matplotlib.transforms as mtransforms
trans = mtransforms.ScaledTranslation(6 / 72, -5 / 72, fig.dpi_scale_trans)
t = ax[0].text(0.0, 1.0, 'a)', transform=ax[0].transAxes + trans,
        fontsize='large', verticalalignment='top')
t.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='None'))
trans = mtransforms.ScaledTranslation(6 / 72, 5 / 72, fig.dpi_scale_trans)
t = ax[1].text(0.0, 0.0, 'b)', transform=ax[1].transAxes + trans,
        fontsize='large', verticalalignment='bottom')
t.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='None'))
fig.align_ylabels()
fig.tight_layout()
fig.savefig(os.path.join(plotFilePath, 'profiles.png'), dpi=300)

# %%
# load hydro data and calculate wave parameters
ds = xr.open_dataset(os.path.join(fold, 'ADV','tailored', 'vec008.nc'))
ds['uc'] = ds.uc.where(ds.uc.min(dim='N')>-2)

dsd = ds.dropna(dim='t', how='any', subset=['u_ss', 'v_ss', 'Tp', 'Ur'])
uss = dsd.u_ss
vss = dsd.v_ss
umag = np.sqrt(uss**2+vss**2)
uorbmax = umag.quantile(0.90, dim='N')
ds['uorbmag'] = umag
ds['uorbmax'] = uorbmax
ds['umean'] = np.sqrt(ds.u.mean(dim='N')**2+ds.v.mean(dim='N')**2)
ds['a'] = np.sqrt(2)*ds.ud_ssm/(2*np.pi/ds.Tp) # significant orbital exursion in wave direction

ds['u_ssm_c'] = np.cos((ds.puvdir-122)/180*np.pi)*ds.u_ssm
ds['u_ssm_l'] = np.sin((ds.puvdir-122)/180*np.pi)*ds.u_ssm

ds['u_ucm'] = ds['uc']-ds['ucm']
ds['u_ss2'] = ds.puv.band_pass_filter_ss('u_ucm',fpminfac=0.5, fpmaxfac=100)
ds['u_ig2'] = ds['u_ucm']-ds['u_ss2']

# %%
# compute acceleration from du/dt and calculate acceleration spike (Drake and Calantoni)
qc = xr.open_dataset(os.path.join(fold, 'ADV','qc','vec008.nc'))

##########################################################################
# extent the dataset with appropriate frequency axis
##########################################################################
print('extending dataset with freq axis')

fresolution = 0.003125


ds2 = xr.Dataset(
    data_vars={},
    coords={'t': ds.t,
            'N': ds.N,
            'f': np.arange(0, ds.sf.values/2+fresolution, fresolution)}
)

ds2['f'].attrs = {'long_name': 'f', 'units': 'Hz'}
ds2['N'].attrs = {'long_name': 'burst time', 'units': 's'}

# copy all data over into this new structure
for key in qc.data_vars:
    ds2[key] = qc[key]
ds2.attrs = ds.attrs

ufunc = lambda u, v: puv.rotate_velocities(u, v, 122)
dsi = ds2.dropna(dim='t',subset=['u', 'v'])
ds2['uc'], ds2['ul'] = xr.apply_ufunc(ufunc,
            dsi['u'], dsi['v'],
            input_core_dims=[['N'], ['N']],
            output_core_dims=[['N'], ['N']],
            vectorize=True)   

ds2['ulpf'] = ds2.puv.band_pass_filter_ss('uc', freqband=[0, 2])
ds2['vlpf'] = ds2.puv.band_pass_filter_ss('ul', freqband=[0, 2])

ds2['alpf'] = ds2.ulpf.differentiate(datetime_unit='s', coord='N')
ds['aspike'] = (ds2.alpf**3).mean(dim='N')/(ds2.alpf**2).mean(dim='N')
# Out:
# extending dataset with freq axis

# %%
# 1D ripple geometry and migration
rib1d = xr.open_dataset(os.path.join(fold, 'SRPS', 'tailored', 'geometrystats1D.nc'))

# add min and max angles of minimum labda
rib1d = rib1d.rename({'thetmin':'phi'})
sel = rib1d.where(rib1d.theta>-45)
rib1d['thetmin'] = sel['theta'].expand_dims(dim={"time": len(sel.time)}).where(sel.labda==rib1d.labdamin).min(dim='theta')
rib1d['thetmax'] = sel['theta'].expand_dims(dim={"time": len(sel.time)}).where(sel.labda==rib1d.labdamin).max(dim='theta')

#remove outliers (if any)
rib1d = rib1d.where(rib1d.etamin<0.25)

ripple_dir = (rib1d.phi).rolling(time=8, min_periods=6, center=True).median()
ripple_dir_offshore = xr.where(ripple_dir<0, ripple_dir+180, ripple_dir-180)

# 1D Migration rates estimate
mig1d = xr.open_dataset(os.path.join(fold, 'SRPS', 'tailored', 'migrationrates_1D.nc'))
mig1d = mig1d.resample(time='15T').nearest(tolerance='10T')

# add direction to migration in 1d
mig1d['phi'] = ripple_dir.interp_like(mig1d.time)

#############
mig1d['tprev'] = mig1d['time']-np.timedelta64(900, 's')
#############

mig1d['deltat'] = ((mig1d.time-mig1d.tprev)/np.timedelta64(1, 's'))

mig1d['dmig_cross'] = np.cos((mig1d.phi)/180*np.pi)*mig1d.dmig
mig1d['vmig_cross'] = mig1d.dmig_cross*3600/(mig1d.deltat)

# %%
# 2D ripple geometry and migration
rib2d = xr.open_dataset(os.path.join(fold, 'SRPS', 'tailored', 'geometrystats_2D.nc'))
spread = xr.open_dataarray(os.path.join(fold, 'SRPS', 'tailored', 'directionalspreading.nc'))

mig = xr.open_dataset(os.path.join(fold, 'SRPS', 'tailored', 'migrationrates2D.nc'))

#make sure that we only include positive time increments
#############
mig['tprev'] = mig['time']-np.timedelta64(900, 's')
#############
mig['deltat'] = ((mig.time-mig.tprev)/np.timedelta64(1, 's'))
mig = mig.where(mig.deltat>0).dropna(dim='time')
mig = mig.resample(time='15T').nearest(tolerance='10T')

# fix the migration direction
mig['phi'] = ('time', np.where((mig['phi']+180)<=180, mig['phi']+180, mig['phi']-180))

# decompose in cross- and alongshore
mig['dmig_cross'] = np.cos((mig.phi)/180*np.pi)*mig.dmig
mig['dmig_along'] = np.sin((mig.phi)/180*np.pi)*mig.dmig
mig['vmig_cross'] = mig.dmig_cross*3600/(mig.deltat)
mig['vmig_along'] = mig.dmig_along*3600/(mig.deltat)

mig['puvdir']   = ds.rename({'t':'time'}).puvdir.interp_like(mig.time)
mig['ulm']      = ds.rename({'t':'time'}).ulm.interp_like(mig.time)
mig['ucm']      = ds.rename({'t':'time'}).ucm.interp_like(mig.time)
mig['uorb']     = ds.rename({'t':'time'}).uorbmax.interp_like(mig.time)
mig['labda3d']  = rib2d.labda.interp_like(mig.time)

# remove unreliable period within the storm
mig = mig.where(np.logical_or(mig.time<pd.to_datetime('20231102 14:15'), mig.time>pd.to_datetime('20231102 19:45')))

# remove migration information when no labda could be reconstructed in 3D
mig = mig.where(~np.isnan(mig.labda3d))

# remove unreliable estimates of more than 35 cm/hr
mig = mig.where(mig.vmig_cross<35)
mig = mig.where(mig.vmig_along<35)

rib2d['vmig_cross'] = mig['vmig_cross']
rib2d['vmig_along'] = mig['vmig_along']
rib2d['p_mig'] = mig['p']
rib2d['spreading'] = spread

# %% [markdown]
# add geometry to the hydro dataset

# %%
pmin = 0.5
pmin1d = 0.7

ds['eta'] = rib1d.etamin.rename({'time':'t'}).interp_like(ds.t)
ds['labda'] = rib1d.labdamin.rename({'time':'t'}).interp_like(ds.t)
ds['phi'] = ripple_dir.rename({'time':'t'}).interp_like(ds.t)
ds['labda3d'] = rib2d.labda.rename({'time':'t'}).interp_like(ds.t)

ds['vmig_cross'] = mig.vmig_cross.where(np.minimum(mig.percvalid1, mig.percvalid2)>0.5).where(mig.p>pmin).rename({'time':'t'}).interp_like(ds.t).where(~np.isnan(ds.labda3d))
ds['vmig_cross1d'] = mig1d.vmig_cross.where(mig1d.p>pmin1d).rename({'time':'t'}).interp_like(ds.t)
ds['vmig_cross_c'] = ('t', np.where(np.isnan(ds.vmig_cross1d), ds.vmig_cross, ds.vmig_cross1d))
ds['vmig_along'] = mig.vmig_along.where(np.minimum(mig.percvalid1, mig.percvalid2)>0.5).where(mig.p>pmin).rename({'time':'t'}).interp_like(ds.t).where(~np.isnan(ds.labda3d))

# %%
def uz2(z, zref, uf, d50=d50, z0=2.5e-3):
    return uf/(np.log((zref-0.7*d50)/z0))*np.log((z-0.7*d50)/z0)

# scale velocity to 5 cm above the bed
z=0.05 
ds['ucm_nb'] = uz2(z, ds['h'], ds['ucm'], d50=d50)
ds['uc_nb'] = ds['uc']-ds['ucm']+ds['ucm_nb']

ds['ulm_nb'] = uz2(z, ds['h'], ds['ulm'], d50=d50) 
ds['ul_nb'] = ds['ul']-ds['ulm']+ds['ulm_nb']

# 
ds['ucm3'] = ds['ucm_nb']*(1-np.cos(ds.phi/180*np.pi)) 
ds['ulm3'] = ds['ulm_nb']*np.cos(ds.phi/180*np.pi) 

ds['uc_3'] = ds['uc']-ds['ucm']+ds['ucm3'] 
ds['ul_3'] = ds['ul']-ds['ulm']+ds['ulm3']

# %%
##############
#%% Figure 4
##############

x0 = np.logspace(-5, 2.4,50)
x = np.concatenate([-np.flipud(x0), x0])
fig, ax = plt.subplots(figsize=[4, 2])
plt.plot(x, np.sign(x)*np.log10(np.abs(x)+1))
plt.axvline(-100, linewidth=0.5, color='k', linestyle=':')
plt.axvline(-50, linewidth=0.5, color='k', linestyle=':')
plt.axvline(-10, linewidth=0.5, color='k', linestyle=':')
plt.axvline(0, linewidth=0.5, color='k', linestyle=':')
plt.axvline(10, linewidth=0.5, color='k', linestyle=':')
plt.axvline(50, linewidth=0.5, color='k', linestyle=':')
plt.axvline(100, linewidth=0.5, color='k', linestyle=':')
plt.axhline(2, linewidth=0.5, color='k', linestyle=':')
plt.axhline(1, linewidth=0.5, color='k', linestyle=':')
plt.axhline(0, linewidth=0.5, color='k', linestyle=':')
plt.axhline(-1, linewidth=0.5, color='k', linestyle=':')
plt.axhline(-2, linewidth=0.5, color='k', linestyle=':')
plt.xticks([-100, -50, -10, 0, 10, 50, 100], fontsize=8)
plt.yticks([-2, -1, 0, 1, 2], fontsize=8)
plt.xlabel(r'$Q_B$ [$\times 10^{-6}$ m$^2$/s]')
plt.ylabel('$Q_b$\' [-]')
plt.axis([-110, 110, -2.2, 2.2])
plt.savefig(os.path.join(plotFilePath, 'logmod_transform.png'), dpi=200, bbox_inches='tight')

# %%
#############
#%% FIGURE 5
#############

# prepare analysis of model fit 
# u-u_cross_ripple
theta_prime_c = shields_parameter_ribberink98(ds.drop_vars(['uc', 'ul']).rename({'uc_3':'uc', 'ul_3':'ul'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=7)
theta_prime_l = shields_parameter_ribberink98(ds.drop_vars(['uc', 'ul']).rename({'uc_3':'uc', 'ul_3':'ul'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=7+1)
theta_prime_mag = np.sqrt(theta_prime_c**2+theta_prime_l**2)
theta_eff = theta_prime_mag -theta_crit

thetlist = list(theta_prime_mag.values.flatten())
thetarr = np.array([t for t in thetlist if not np.isnan(t)])

thetlistc = list(theta_prime_c.values.flatten())
thetarrc = np.array([t for t in thetlistc if not np.isnan(t)])

# plt.figure(figsize=[5, 3])
# plt.hist(thetarr, bins=150, range=[0,3], label='magnitude');
# plt.hist(np.abs(thetarrc), bins=150, range=[0, 3], alpha=0.5, label='cross-shore');
# plt.yscale('log')
# plt.xscale('log')
# plt.xlabel(r'$\theta$')
# plt.axvline(theta_crit, c='k')
# plt.ylabel('count [-]')
# plt.xlim([1e-2, 1e1])
# plt.title('Shields Parameter')

theta_prime_rms=np.sqrt((theta_prime_mag**2).mean(dim='N'))
theta_prime_max=(np.abs(theta_prime_mag)).quantile(0.90, dim='N')

fig, ax = plt.subplots(7, 1, figsize=[8, 9], sharex=True)

ax[0].plot(ds.t, (ds.zs-ds.zb), label='obs', color='k')
ax[0].set_ylabel('$h$ [m]')
ax[0].set_ylim([0, 2.5])
hm02 = np.where(np.isnan(ds.u_ssm), np.nan, ds.Hm0)
ax[1].plot(ds.t, hm02, label='obs', color='k', linestyle='-')
tax = ax[1].twinx()

# marker for the ACVP measurement
ymax = 2.5
start = mdates.date2num( (pd.to_datetime('20231102 01:00')-pd.Timedelta('2H')).to_pydatetime() )
middle = mdates.date2num( (pd.to_datetime('20231102 01:00')).to_pydatetime() )
end   = mdates.date2num( (pd.to_datetime('20231102 01:00')+pd.Timedelta('2H')).to_pydatetime() )
ax[0].add_artist(mlines.Line2D([start, middle, end, start], [ymax+0.3, ymax, ymax+0.3, ymax+0.3], lw=1.2, color='k', clip_on=False))

ax[1].set_ylabel('$H_{m0}$ [m]')
ds.u_ssm.plot(label='obs', color='C0', linestyle=':', ax=tax)
tax.set_title('')
tax.set_ylabel('$u_{rms}$ [m/s]', color='C0')
ax[1].set_ylim([0, 0.9])
ax[1].set_yticks([0, 0.3, 0.6])
tax.set_ylim([0, 0.45])
tax.set_yticks([0, 0.3])
tax.set_yticklabels([0, 0.3], c='C0')

t2 = np.where(np.isnan(ds.u_ssm), np.nan, ds.Tmm10)
ax[2].plot(ds.t, t2, label='obs', linestyle='-', color='k')
ax[2].set_ylabel('$T_{m-1,0}$ [s]', color='k')
ax[2].set_ylim([0, 5.5])
ax[2].set_yticks([0, 2, 4])
tax22 = ax[2].twinx()

k2 = np.where(np.isnan(ds.u_ssm), np.nan, ds.k)
tax22.plot(ds.t, 1/(k2*ds.d), color='C0', linestyle=':')
tax22.set_ylabel('1/kh [-]', color='C0')
tax22.set_ylim([0, 2+1.5/4*2])
tax22.set_yticks([0, 2])
tax22.set_yticklabels([0, 2], c='C0')

tax3 = ax[3].twinx()
(ds.ucm).plot(label='across', color='k', ax=ax[3])
(ds.ulm).plot(label='along', color='C0', linestyle=':', ax=tax3)
ax[3].set_ylabel('$u_{cross}$ [m/s]', color='k')
tax3.set_ylabel('$u_{along}$ [m/s]', color='C0')
tax3.set_title('')
ax[3].set_ylim([-0.15, 0.05])
tax3.set_ylim([-0.45, 0.15])
tax3.set_yticks([-0.3, 0])
tax3.set_yticklabels([-0.3, 0], c='C0')

(ds.nSk).plot(label='$S_u$', color='k', ax=ax[4])
tax4 = ax[4].twinx()
(ds.nAs).plot(label='$A_u$', color='C0', linestyle=':', ax=tax4)
ax[4].set_ylabel('$S_u$ [-]', color='k')
tax4.set_ylabel('$A_u$ [-]', color='C0')
ax[4].set_ylim([-0.5, 0.75])
tax4.set_ylim([-0.5, 0.75])
tax4.set_yticklabels([-0.5, 0, 0.5], c='C0')
tax4.set_title('')

ax[5].plot(ds.t,((ds.puvdir)%360-122), label='obs', color='k')
tax5 = ax[5].twinx()
thetc = np.arctan2(ds.ulm, ds.ucm)*180/np.pi-123
thetc = np.where(thetc<180, thetc, thetc-360)
thetc = np.where(thetc>-180, thetc, thetc+360)
tax5.plot(ds.t, thetc, color='C0', ms=2, marker='.', linestyle='None')
ax[5].set_ylabel(r'$\vartheta_w$ [$^\circ$]', color='k')
tax5.set_ylabel(r'$\vartheta_c$ [$^\circ$]', color='C0')
tax5.set_title('')
ax[5].set_ylim([-90, 90])
tax5.set_ylim([-180, 180])
tax5.set_yticks([-90, 0, 90])
tax5.set_yticklabels([-90, 0, 90], c='C0')
ax[5].set_yticks([-45, 0, 45])

# investigate criterion for initiation of saltation and suspension
ax[6].axhline(0.17, c='r', linewidth=1)
ax[6].axhline(theta_crit, c='green', linewidth=1)
ax[6].plot(theta_prime_mag.t, theta_prime_mag.mean(dim='N'), label=' mean', c='k')
ax[6].plot(theta_prime_rms.t, theta_prime_rms, label='rms', c='k', linestyle='--', linewidth=1)
ax[6].plot(theta_prime_max.t, theta_prime_max, label='max', c='k', linestyle=':', linewidth=0.6)

ax[6].set_ylabel(r'$|\theta|$ [-]')
ax[6].set_ylim(bottom=0)

# prettifying
for axi in ax[:-1]:
    axi.set_xlabel('')

ax[1].set_xlim(ds.t.min(), pd.to_datetime('20231109 04:00'))
fig.align_ylabels()
ax[-1].xaxis.set_major_formatter(DateFormatter('%m-%d'))
for axin in ax:
    axin.set_title('')
    axin.grid(linestyle=':', color='grey', linewidth=0.5)
fig.subplots_adjust(hspace=0.06)

import matplotlib.transforms as mtransforms
trans = mtransforms.ScaledTranslation(6 / 72, -5 / 72, fig.dpi_scale_trans)
for label, axi in zip(['a)', 'b)','c)', 'd)','e)', 'f)', 'g)'], ax):
    t = axi.text(0.0, 1.0, label, transform=axi.transAxes + trans,
            fontsize='large', verticalalignment='top')
    t.set_bbox(dict(facecolor='white', alpha=0.8, edgecolor='None'))

ax[-1].text(1, -0.3, 'mm-dd in 2023',transform = ax[-1].transAxes, ha='right', va='top')

plt.savefig(os.path.join(plotFilePath, 'ts_hydro.png'), dpi=200, bbox_inches='tight')
# Out:
# c:\Users\marliesvanderl\AppData\Local\miniforge3\envs\work\Lib\site-packages\numpy\lib\nanfunctions.py:1577: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# C:\Users\marliesvanderl\AppData\Local\Temp\ipykernel_18852\3895131841.py:90: UserWarning: FixedFormatter should only be used together with FixedLocator
#   tax4.set_yticklabels([-0.5, 0, 0.5], c='C0')

# %%
############
#%% FIGURE 7
############

# only on those moments that p is sufficiently high
fig, ax = plt.subplots(5,1, sharex=True, figsize=[8, 5])

ax[0].plot(rib2d['time'], rib2d['eta'], marker='.', linestyle='None', color='blue', ms=3)
ax[0].plot(rib1d['time'], rib1d['etamin'], marker='.', linestyle='None', color='red', ms=3)

# marker for the ACVP measurement
ymax = ax[0].get_ylim()[1]
start = mdates.date2num( (pd.to_datetime('20231102 01:00')-pd.Timedelta('90min')).to_pydatetime() )
middle = mdates.date2num( (pd.to_datetime('20231102 01:00')).to_pydatetime() )
end   = mdates.date2num( (pd.to_datetime('20231102 01:00')+pd.Timedelta('90min')).to_pydatetime() )
ax[0].add_artist(mlines.Line2D([start, middle, end, start], [ymax+0.02, ymax, ymax+0.02, ymax+0.02], lw=1.0, color='k', clip_on=False))


ax[1].plot(rib2d['time'], rib2d['labda'], marker='.', linestyle='None', color='blue', ms=3)
ax[1].plot(rib1d['time'], rib1d['labdamin'], marker='.', linestyle='None', color='red', ms=3)
ax[1].set_ylim([0, 0.5])

ax[2].scatter(rib2d['time'], rib2d['phi'], color='blue', s=3)
ax[2].scatter(rib1d['time'], rib1d['phi'], color='red', s=3)
ax[2].set_ylabel(r'$\phi$ [deg]')
ax[2].set_ylim([-50, 50])

ax[3].scatter(rib2d['time'], rib2d['eta']/rib2d['labda'], marker='.', linestyle='None', color='blue', s=3)
ax[3].scatter(rib1d['time'], rib1d['etamin']/rib1d['labdamin'], marker='.', linestyle='None', color='red', s=3)
ax[3].set_ylabel(r'$\eta/\lambda$ [-]')
ax[3].axhline(0.12, color='k', linestyle=':', linewidth=1)
ax[3].axhline(0.15, color='k', linestyle='--', linewidth=1)
ax[3].set_ylim([0, 0.4])

ax[4].plot(rib2d.time, rib2d.spreading, marker='.', linestyle='None', color='blue', ms=2)
ax[4].set_ylabel('$S_{3D}$ [$^\circ$]')
ax[4].set_ylim([0, 90])
ax[4].set_yticks([0, 22.5, 45, 67.7, 90])
ax[4].set_yticklabels(['0','', '45', '', '90'])
ax[4].axhline(45, linewidth=0.5, color='k', linestyle=':')
ax[4].axhline(22.5, linewidth=0.5, color='k', linestyle=':')
ax[0].legend(['footprint', 'single-swath'], ncols=2, loc='best')
ax[0].set_ylabel('$\eta$ [m]')
ax[0].set_ylim([0, 0.15])
ax[1].set_ylabel('$\lambda$ [m]')

# plot_migrating_moments(ax)
ax[-1].set_xlim([mig.time.min(), mig.time.max()])
ax[-1].xaxis.set_major_formatter(DateFormatter('%m-%d'))

fig.align_ylabels()
from scipy import signal
ii = signal.find_peaks(-ds.d, distance=pd.to_timedelta('5H')/(ds.t[1]-ds.t[0]))[0]
for axi in ax:
    for i in ii:
        ti = ds.t.isel(t=i).values
        d = ds.d.isel(t=i).values
        if (d<1.45):
            axi.axvline(ti, color='k', linewidth=0.5)

ax[-1].text(1, -0.38, 'mm-dd in 2023',transform = ax[-1].transAxes, ha='right', va='top')

import matplotlib.transforms as mtransforms
trans = mtransforms.ScaledTranslation(6 / 72, -5 / 72, fig.dpi_scale_trans)
for label, axi in zip(['a)', 'b)', 'c)', 'd)', 'e)'], ax):
    t = axi.text(0.0, 1.0, label, transform=axi.transAxes + trans,
            fontsize='large', verticalalignment='top')
    t.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='None'))

plt.savefig(os.path.join(plotFilePath, '1D_2D_stats.png'), dpi=200, bbox_inches='tight')

# %%
##############
#%% FIGURE 8
##############
relict_times0 = [
    ds.t.sel(t=slice('20231103 01:00', '20231103 03:00')).values,
    ds.t.sel(t=slice('20231103 07:30','20231103 10:30')).values,
    ds.t.sel(t=slice('20231105 07:30', '20231105 16:30')).values,
    ds.t.sel(t=slice('20231105 21:00', '20231106 03:30')).values,
    ds.t.sel(t=slice('20231106 20:00', '20231107 06:30')).values,
    ds.t.sel(t=slice('20231107 11:00', '20231107 15:30')).values,
    ds.t.sel(t=slice('20231107 22:00', '20231108 07:00')).values,
    ds.t.sel(t=slice('20231108 22:30', '20231109 12:00')).values,
]

relict_times = [x for xs in relict_times0 for x in xs]

# clifton diagram
from matplotlib.patches import Polygon 

# ripple cutof
umag = np.sqrt(ds.u_ss**2+ds.v_ss**2)
uorbmax = umag.quantile(0.90, dim='N')
ds['uorbmax'] = uorbmax
d0 = ds['Tmm10']*ds['uorbmax']/np.pi  # according to clifton and dingler the orbital excursion with here uorbmax is 90%

fig, ax = plt.subplots(2, 2, figsize=[8,4], gridspec_kw={'height_ratios': [3, 1]})
ax = [ax[0,0], ax[0, 1], ax[1,:]]

gs = ax[2][0].get_gridspec()
# remove the underlying Axes
ax[2][0].remove()
ax[2][1].remove()
axbig = fig.add_subplot(gs[-1, 0:])

ax[0].scatter(d0/630e-6, ds['labda']/630e-6, label='all data', s=2)
ax[0].scatter(d0.sel(t=relict_times)/630e-6, ds.sel(t=relict_times)['labda']/630e-6, label='relic', s=2) 


# Miller and Komar 1980 a, as mentioned in Clifton and Dinler 1984 equation 8
ax[0].plot(np.linspace(0, 5, 100)/600e-6, 0.65*np.linspace(0, 5, 100)/600e-6, label='Miller and Komar (1980)', linestyle='--', color='k')  
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].set_xlim([1e2, 1e5])
ax[0].set_ylim([1e2, 5e3])
ax[0].set_xlabel('$d_0/D$')
ax[0].set_ylabel('$\lambda/D$')
ax[0].axvline(1e3, linestyle='--', color='k', linewidth=0.5)
ax[0].axvline(4.5e3, linestyle='--', color='k', linewidth=0.5)
r = Polygon([(1e2, 4e1), (5.5e3, 2e3), (3.2e3, 3.0e3), (1e2, 1e2)], color='grey', alpha=0.5, zorder=-2)
ax[0].add_patch(r)
r = Polygon([(5.5e3, 2e3), (2e3, 7e2), (2e4, 7e2)], color='lightgrey', alpha=0.5, zorder=-2)
ax[0].add_patch(r)
r = Polygon([(5.5e3, 5e2), (5e4, 5e2), (5e4, 8e2), (5.5e3, 8e2)], color='darkgrey', alpha=0.8, zorder=-2)
ax[0].add_patch(r)
# ax[0].legend()
ax[0].text(3e2, 1.5e2, 'orbital ripples', ha='left', va='bottom', rotation=50, fontsize=8)
ax[0].text(5.5e3, 1.5e3,'suborbital\n ripples', ha='center', va='top', fontsize=8)
ax[0].text(1.6e4, 7e2,'anorbital\n ripples', ha='center', va='top', fontsize=8)

ax[1].scatter(d0/630e-6, ds['eta']/ds['labda'], s=2, zorder=-2) 
ax[1].scatter(d0.sel(t=relict_times)/630e-6, (ds['eta']/ds['labda']).sel(t=relict_times), s=2) # relict
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].set_xlim([1e2, 2e4])
ax[1].set_ylim([1e-2, 1e0])
ax[1].set_xlabel('$d_0/D$')
ax[1].set_ylabel('$\eta/\lambda$')
ax[1].axhline(1.2e-1, linestyle='-.', color='k', linewidth=0.5)
ax[1].axvline(1e3, linestyle='--', color='k', linewidth=0.5)
ax[1].axvline(4.5e3, linestyle='--', color='k', linewidth=0.5)
ax[1].text(0.9e3, 8e-1, 'Orbital', ha='right', va='top', fontsize=8)
ax[1].text(0.9e3, 6e-1, 'ripples', ha='right', va='top', fontsize=8)
ax[1].text(1.5e4, 1.7e-1, 'VORTEX', ha='right', va='top', fontsize=10)
ax[1].text(5.0e3, 8e-1, 'Anorbital', ha='left', va='top', fontsize=8)
ax[1].text(5.0e3, 6e-1, 'ripples', ha='left', va='top', fontsize=8)
ax[1].text(1.5e2, 4e-2, 'PRE-VORTEX', ha='left', va='top', fontsize=10)
ax[1].text(1.5e4, 1.1e-1, 'POST-VORTEX', ha='right', va='top', fontsize=10)

axbig.scatter(ds.t, ds.labda, s=2, label='orbital')
axbig.scatter(ds.sel(t=relict_times).t, ds.sel(t=relict_times).labda, s=2, label='relict')
axbig.legend(ncols=2)
axbig.set_ylabel('$\lambda$ [m]')
axbig.xaxis.set_major_formatter(DateFormatter('%m-%d'))

fig.tight_layout()

import matplotlib.transforms as mtransforms
trans = mtransforms.ScaledTranslation(6 / 72, -5 / 72, fig.dpi_scale_trans)
for label, axi in zip(['a)', 'b)', 'c)'], [ax[0], ax[1], axbig]):
    t = axi.text(0.0, 1.0, label, transform=axi.transAxes + trans,
            fontsize='large', verticalalignment='top')
    t.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='None'))

plt.savefig(plotFilePath, dpi=200, bbox_inches='tight')
# Out:
# c:\Users\marliesvanderl\AppData\Local\miniforge3\envs\work\Lib\site-packages\numpy\lib\nanfunctions.py:1577: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,

# %%
rel = ds[['labda','eta']].sel(t=relict_times).dropna(dim='t')
all = ds[['labda','eta']].dropna(dim='t')
orb = ds[['labda','eta']].sel(t=np.setdiff1d(ds.t.values, relict_times)).dropna(dim='t')
print('orbital = {:.0f}%'.format(100*len(orb.labda.values)/len(all.labda.values)))
print('relict = {:.0f}%'.format(100*len(rel.labda.values)/len(all.labda.values)))
print('orbital vortex = {:.0f}%'.format(100*((orb.eta/orb.labda)>0.12).sum().values/len(orb.labda.values)))
print('relict vortex = {:.0f}%'.format(100*((rel.eta/rel.labda)>0.12).sum().values/len(rel.labda.values)))
# Out:
# orbital = 68%
# relict = 32%
# orbital vortex = 91%
# relict vortex = 86%

# %%
#############
#%% FIGURE 9
#############

# Just for visualizing, load a dataset version with the cross-shore transect timestack included
dscros = xr.open_dataset(os.path.join(fold, 'SRPS', 'tailored', 'migration_cross.nc'))

fig, ax = plt.subplots(4, 1, figsize=[8, 6], sharex=True, height_ratios= [3,1,1, 1])
Y,X =np.meshgrid(-dscros['x'], dscros['time'])
im=ax[0].pcolor(X, Y, dscros['zb1'].values, vmin=-0.05, vmax=0.05, cmap='RdBu')
ax[0].set_ylabel('cross-shore [m]')
# plt.colorbar(im)

ax[1].plot(ds.t, ds.phi.rolling(t=1).mean(), color='k', linewidth=1.2)
ax[1].set_ylabel('$\phi$ [$^{\circ}$]')

ax[2].scatter(mig1d['time'], mig1d['vmig_cross'].where(mig1d.p>0.5), marker='s', s=3, color='None', edgecolor='k', label='cross')
ax[2].set_ylabel('$v_{mig}$ 2D\n [cm/hr]')
ax[2].set_ylim([-35, 35])
ax[2].axhline(0, color='k', linewidth=0.5, zorder=-2)

ax[3].scatter(ds['t'], ds['vmig_along'], marker='o', s=4, color='None', edgecolor='C1', label='along')
ax[3].scatter(ds['t'], ds['vmig_cross'], marker='s', s=7, color='None', edgecolor='k', label='cross')

ax[3].axhline(0, color='k', linewidth=0.5, zorder=-2)
ax[3].set_ylim([-35, 35])
ax[3].set_ylabel('$v_{mig}$ 3D\n [cm/hr]')
ax[3].legend(ncol=2, loc='best', bbox_to_anchor=(0.4, 0., 0.5, 0.5))
ax[3].xaxis.set_major_formatter(DateFormatter('%m-%d'))

alpha=0.1
for axi in ax[1:2]:
    axi.axvspan(pd.to_datetime('20231102 02:30'), pd.to_datetime('20231102 05:30'), alpha=alpha, color='grey') # missing data
    axi.axvspan(pd.to_datetime('20231104 15:30'), pd.to_datetime('20231104 17:45'), alpha=alpha, color='grey') # missing data

for axi in ax[2:3]:
    axi.axvspan(pd.to_datetime('20231101 18:0'), pd.to_datetime('20231102 20:00'), alpha=alpha, color='grey') # missing data
    axi.axvspan(pd.to_datetime('20231104 15:30'), pd.to_datetime('20231104 18:15'), alpha=alpha, color='grey') # missing data

for axi in ax[3:4]:
    axi.axvspan(pd.to_datetime('20231102 02:30'), pd.to_datetime('20231102 06:30'), alpha=alpha, color='grey') # missing data
    axi.axvspan(pd.to_datetime('20231102 14:00'), pd.to_datetime('20231102 20:00'), alpha=alpha, color='grey') # missing data
    axi.axvspan(pd.to_datetime('20231104 15:30'), pd.to_datetime('20231104 18:15'), alpha=alpha, color='grey') # missing data

plot_migrating_moments(ax[1:4], alpha=alpha)
fig.tight_layout()
fig.subplots_adjust(hspace=0.02)

import matplotlib.transforms as mtransforms
trans = mtransforms.ScaledTranslation(6 / 72, -5 / 72, fig.dpi_scale_trans)
for label, axi in zip(['a)', 'b)', 'c)', 'd)'], ax):
    t = axi.text(0.0, 1.0, label, transform=axi.transAxes + trans,
            fontsize='large', verticalalignment='top')
    t.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='None'))

ax[-1].text(1, -0.3, 'mm-dd in 2023',transform = ax[-1].transAxes, ha='right', va='top')

plt.savefig(os.path.join(plotFilePath, 'cross-shoremigration_axvspan.png'), dpi=200, bbox_inches='tight')

# %%
# Figure 10
vmin = 1 
s=30
from matplotlib.gridspec import GridSpec
fig = plt.figure(figsize=[8, 1.8])

gs1 = GridSpec(1,1, left=0, right=0.16, wspace=0.05)
ax1 = fig.add_subplot(gs1[0])

gs2 = GridSpec(1,4, left=0.25, right=1, hspace=0.05)
ax2 = fig.add_subplot(gs2[0])
ax3 = fig.add_subplot(gs2[1])
ax4 = fig.add_subplot(gs2[2])
ax5 = fig.add_subplot(gs2[3])
# ax = [*ax[0,:], *ax[1,:]]
ax=[ax1, ax2, ax3, ax4, ax5]

q = ds.vmig_along.where(ds.vmig_cross_c**2>vmin)
q2 = ds.vmig_along
qs = ds.ulm
ax[0].scatter(qs, q2,c='red', edgecolor='None', linewidth=0.5, s=s)
ax[0].scatter(qs, q,c='None', edgecolor='k', linewidth=0.5, s=s)
ax[0].set_xlim([-0.5, 0.5])
ax[0].set_ylabel('$v_{mig, along}$ [cm/hr]')
ax[0].set_xlabel('$\overline{u}_{along}$ [m/s]')
ax[0].text(0.58, 0.22, 'r={:.2f}'.format(spearman_stats(qs, q2).correlation), transform=ax[0].transAxes, c='r', ha='left', va='top', fontsize=10)
print(spearman_stats(qs, q2))
ax[0].text(0.58, 0.12, 'r={:.2f}'.format(spearman_stats(qs, q).correlation), transform=ax[0].transAxes, ha='left', va='top', fontsize=10)
print(spearman_stats(qs, q))

q = ds.vmig_cross_c.where(ds.vmig_cross_c**2>vmin)
q2 = ds.vmig_cross_c
qs = ds.ucm
ax[1].scatter(qs, q2, c='red', edgecolor='None', linewidth=0.5, s=s)
ax[1].scatter(qs, q, c='None', edgecolor='k', linewidth=0.5, s=s)
ax[1].set_xlim([-0.12, 0.12])
ax[1].set_ylabel('$v_{mig, cross}$ [cm/hr]')
ax[1].set_xlabel('$\overline{u}_{cross}$ [m/s]')
ax[1].text(0.6, 0.22, 'r={:.2f}'.format(spearman_stats(qs, q2).correlation), transform=ax[1].transAxes, c='r', ha='left', va='top', fontsize=10)
print(spearman_stats(qs, q2))
ax[1].text(0.6, 0.12, 'r={:.2f}'.format(spearman_stats(qs, q).correlation), transform=ax[1].transAxes, ha='left', va='top', fontsize=10)
print(spearman_stats(qs, q))

qs = np.abs(ds.ulm)
ax[2].scatter(qs, q2,c='red', edgecolor='None', linewidth=0.5, s=s)
ax[2].scatter(qs, q,c='None', edgecolor='k', linewidth=0.5, s=s)
ax[2].set_xlim([-0.5, 0.5])
ax[2].set_xlabel('$\overline{u}_{along}}$ [m/s]')
ax[2].text(0.05, 0.22, 'r={:.2f}'.format(spearman_stats(qs, q2).correlation), transform=ax[2].transAxes, c='r', ha='left', va='top', fontsize=10)
print(spearman_stats(qs, q2))
ax[2].text(0.05, 0.12, 'r={:.2f}'.format(spearman_stats(qs, q).correlation), transform=ax[2].transAxes, ha='left', va='top', fontsize=10)
print(spearman_stats(qs, q))

qs = ds.Sk/ds.sig**3
ax[3].scatter(qs, q2, c='red', edgecolor='None', linewidth=0.5, s=s)
ax[3].scatter(qs, q, c='None', edgecolor='k', linewidth=0.5, s=s)
ax[3].set_xlim([-1, 1])
ax[3].set_xlabel('$S_u$ [-]')
ax[3].text(0.05, 0.22, 'r={:.2f}'.format(spearman_stats(qs, q2).correlation), transform=ax[3].transAxes, c='r', ha='left', va='top', fontsize=10)
print(spearman_stats(qs, q2))
ax[3].text(0.05, 0.12, 'r={:.2f}'.format(spearman_stats(qs, q).correlation), transform=ax[3].transAxes, ha='left', va='top', fontsize=10)
print(spearman_stats(qs, q))

qs = ds.As/ds.sig**3
ax[4].scatter(qs, q2, c='red', edgecolor='None', linewidth=0.5, s=s)
ax[4].scatter(qs, q, c='None', edgecolor='k', linewidth=0.5, s=s)
ax[4].set_xlim([-0.5, 0.5])
ax[4].set_xlabel('$A_u$ [-]')
ax[4].text(0.56, 0.22, 'r={:.2f}'.format(spearman_stats(qs, q2).correlation), transform=ax[4].transAxes, c='r', ha='left', va='top', fontsize=10)
print(spearman_stats(qs, q2))
ax[4].text(0.56, 0.12, 'r={:.2f}'.format(spearman_stats(qs, q).correlation), transform=ax[4].transAxes, ha='left', va='top', fontsize=10)
print(spearman_stats(qs, q))

for axi in ax:
    axi.set_ylim([-45, 45])
    axi.axhline(0, c='grey', zorder=-2, linewidth=0.5)
    axi.axvline(0, c='grey', zorder=-2, linewidth=0.5)

for axi in [ax[0], ax[1]]:
        axi.set_yticks([-25, 0, 25])
        axi.set_yticklabels([-25, 0, 25])
for axi in [ax[2], ax[3], ax[4]]:
        axi.set_yticks([-25, 0, 25])
        axi.set_yticklabels(['', '', ''])
# fig.tight_layout()

import matplotlib.transforms as mtransforms
trans = mtransforms.ScaledTranslation(6 / 72, -5 / 72, fig.dpi_scale_trans)
for label, axi in zip(['a)', 'b)', 'c)', 'd)', 'e)'], ax):
    t = axi.text(0.0, 1.0, label, transform=axi.transAxes + trans,
            fontsize='large', verticalalignment='top')
    t.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='None'))

plt.savefig(os.path.join(plotFilePath, 'migdrivers.png'), dpi=200, bbox_inches='tight')
# Out:
# SignificanceResult(statistic=0.359355989997368, pvalue=1.962482140037012e-11)
# SignificanceResult(statistic=0.565543461924959, pvalue=6.001715679292905e-13)
# SignificanceResult(statistic=0.07906727619206069, pvalue=0.05309876148399881)
# SignificanceResult(statistic=0.1619600910296866, pvalue=0.03326378621227009)
# SignificanceResult(statistic=0.035048532781396344, pvalue=0.3918507707279584)
# SignificanceResult(statistic=-0.170867834470412, pvalue=0.024596708407099176)
# SignificanceResult(statistic=0.1098349239917838, pvalue=0.007425904114478836)
# SignificanceResult(statistic=0.3556960128072935, pvalue=1.5666989480881013e-06)
# SignificanceResult(statistic=-0.19851622846839728, pvalue=1.1016028404796941e-06)
# SignificanceResult(statistic=-0.4187737680290443, pvalue=9.813328148778176e-09)

# %%
# Combine 1D and 2D analysis into one timeseries, where migration is estimated from 1D analysis where possible, and from 2D analysis otherwise. 
# give some values to put into the text
qb2d = ds['vmig_cross']/3600/100*ds['eta']*0.5*(1-0.3)
qmin = qb2d[qb2d>0].max()
qmax= qb2d[qb2d<0].min()
print('from 2d analysis: qmin={:.1e} m2/s and qmax = {:.1e} m2/s'.format(qmin, qmax))

qb1d = mig1d.vmig_cross.rename({'time':'t'}).interp_like(ds.t)/3600/100*ds['eta']*0.5*(1-0.3)
qmin = qb1d[qb1d>0].max()
qmax= qb1d[qb1d<0].min()
print('from 1d analysis: qmin={:.1e} m2/s and qmax = {:.1e} m2/s'.format(qmin, qmax))
print('from 1d analysis in logtransform: qmin={:.2f} and qmax = {:.2f}'.format(np.sign(1e6*qmin)*np.log(np.abs(1e6*qmin)+1), np.sign(1e6*qmax)*np.log(np.abs(1e6*qmax)+1)))

print('\n Were going to remove some outliers: \n')
ii = np.sign(1e6*qb1d)*np.log(np.abs(1e6*qb1d)+1)
qd1 = np.where(ii<2, np.where(ii>-2,qb1d, np.nan), np.nan)
ii = np.sign(1e6*qb2d)*np.log(np.abs(1e6*qb2d)+1)
qd2 = np.where(ii<2, np.where(ii>-2,qb2d, np.nan), np.nan)

qd = np.where(~np.isnan(qd1), qd1, qd2)

qmin = qd1[qd1>0].max()
qmax= qd1[qd1<0].min()
print('from 1d analysis: qmin={:.1e} m2/s and qmax = {:.1e} m2/s'.format(qmin, qmax))
print('from 1d analysis in logtransform with bounds: qmin={:.2f} and qmax = {:.2f}'.format(np.sign(1e6*qmin)*np.log(np.abs(1e6*qmin)+1), np.sign(1e6*qmax)*np.log(np.abs(1e6*qmax)+1)))

qmin = qd[qd>0].max()
qmax= qd[qd<0].min()
print('from comb analysis: qmin={:.1e} m2/s and qmax = {:.1e} m2/s'.format(qmin, qmax))
print('from comb analysis in logtransform with bounds: qmin={:.2f} and qmax = {:.2f}'.format(np.sign(1e6*qmin)*np.log(np.abs(1e6*qmin)+1), np.sign(1e6*qmax)*np.log(np.abs(1e6*qmax)+1)))

ds['Tcross'] = ('t', np.sign(1e6*qd)*np.log(np.abs(1e6*qd)+1))
ds['Tcross_dimensional'] = ('t', qd)
# ds['vmig_cross_comb'] = qd1
# Out:
# from 2d analysis: qmin=1.6e-06 m2/s and qmax = -2.7e-06 m2/s
# from 1d analysis: qmin=9.1e-06 m2/s and qmax = -1.2e-05 m2/s
# from 1d analysis in logtransform: qmin=2.31 and qmax = -2.56
#
#  Were going to remove some outliers:
#
# from 1d analysis: qmin=6.2e-06 m2/s and qmax = -5.8e-06 m2/s
# from 1d analysis in logtransform with bounds: qmin=1.98 and qmax = -1.92
# from comb analysis: qmin=6.2e-06 m2/s and qmax = -5.8e-06 m2/s
# from comb analysis in logtransform with bounds: qmin=1.98 and qmax = -1.92

# %%
# Evaluate the Ribberink Bedload model with different velocity estimates, and see how the predicted bedload transport compares to the observed migration.
# total velocity
theta_prime_c = shields_parameter_ribberink98(ds, d50, g=g, rho_s=rho_s, rho_w=rho_w, option=7)
theta_prime_l = shields_parameter_ribberink98(ds, d50, g=g, rho_s=rho_s, rho_w=rho_w, option=7+1)
theta_prime_mag = np.sqrt(theta_prime_c**2+theta_prime_l**2)
theta_eff = theta_prime_mag -theta_crit
percexceed0 = (theta_eff>0).sum(dim='N')/len(ds.N)*100
q0 = 1e6*bedload_ribberink98(ds, d50=d50, option=7, n=n)
qp0= np.sign(q0)*np.log(np.abs(q0)+1)

#total velocity near bed
theta_prime_c = shields_parameter_ribberink98(ds.drop_vars(['uc', 'ul']).rename({'uc_nb':'uc', 'ul_nb':'ul'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=7)
theta_prime_l = shields_parameter_ribberink98(ds.drop_vars(['uc', 'ul']).rename({'uc_nb':'uc', 'ul_nb':'ul'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=7+1)
theta_prime_mag = np.sqrt(theta_prime_c**2+theta_prime_l**2)
theta_eff = theta_prime_mag -theta_crit
percexceed1 = (theta_eff>0).sum(dim='N')/len(ds.N)*100
q1 = 1e6*bedload_ribberink98(ds.drop_vars(['uc', 'ul']).rename({'uc_nb':'uc', 'ul_nb':'ul'}), d50=d50, option=7, n=n)
qp1= np.sign(q1)*np.log(np.abs(q1)+1)

# u-u_cross_ripple
theta_prime_c = shields_parameter_ribberink98(ds.drop_vars(['uc', 'ul']).rename({'uc_3':'uc', 'ul_3':'ul'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=7)
theta_prime_l = shields_parameter_ribberink98(ds.drop_vars(['uc', 'ul']).rename({'uc_3':'uc', 'ul_3':'ul'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=7+1)
theta_prime_mag = np.sqrt(theta_prime_c**2+theta_prime_l**2)
theta_eff = theta_prime_mag -theta_crit
percexceed5 = (theta_eff>0).sum(dim='N')/len(ds.N)*100
q5 = 1e6*bedload_ribberink98(ds.drop_vars(['uc', 'ul']).rename({'uc_3':'uc', 'ul_3':'ul'}), d50=d50, option=7, n=n)
qp5 = np.sign(q5)*np.log(np.abs(q5)+1)

# no IG
theta_prime_c = shields_parameter_ribberink98(ds.drop_vars(['ul', 'ucm']).rename({'ul_3':'ul'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=49)
theta_prime_l = shields_parameter_ribberink98(ds.drop_vars(['ul', 'ucm']).rename({'ul_3':'ul'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=49+1)
theta_prime_mag = np.sqrt(theta_prime_c**2+theta_prime_l**2)
theta_eff = theta_prime_mag -theta_crit
percexceed3 = (theta_eff>0).sum(dim='N')/len(ds.N)*100
q3 = 1e6*bedload_ribberink98(ds.drop_vars(['ul', 'ucm']).rename({'ul_3':'ul'}), d50=d50, option=49, n=n)
qp3 = np.sign(q3)*np.log(np.abs(q3)+1)

# %%
# transport in longshore direction!
theta_prime_c = shields_parameter_ribberink98(ds.drop_vars(['uc', 'ul']).rename({'uc_3':'uc', 'ul_3':'ul'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=7)
theta_prime_l = shields_parameter_ribberink98(ds.drop_vars(['uc', 'ul']).rename({'uc_3':'uc', 'ul_3':'ul'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=7+1)
theta_prime_mag = np.sqrt(theta_prime_c**2+theta_prime_l**2)
theta_eff = theta_prime_mag -theta_crit
percexceedl5 = (theta_eff>0).sum(dim='N')/len(ds.N)*100
ql5 = 1e6*bedload_ribberink98(ds.drop_vars(['uc', 'ul']).rename({'uc_3':'uc', 'ul_3':'ul'}), dir='along', d50=d50, option=7, n=n)
qpl5 = np.sign(ql5)*np.log(np.abs(ql5)+1)

# %%
# evaluate the effect of the transverse bedload effect
bedslope = xr.open_dataset(os.path.join(fold, 'SRPS', 'tailored', 'bedslope.nc'))
bedslope = bedslope.rolling(t=24).mean().interp_like(ds.t)
qx_slope = -np.abs(ql5)*bedslope.slope
qpx_slope = -np.abs(qpl5)*bedslope.slope

# %%
# to include in the rebuttal:
# only u_ss and u
theta_prime_c = shields_parameter_ribberink98(ds.rename({'ucm_nb': 'ucm_nb2', 'ulm_nb': 'ulm_nb2'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=47)
theta_prime_l = shields_parameter_ribberink98(ds.rename({'ucm_nb': 'ucm_nb2', 'ulm_nb': 'ulm_nb2'}), d50, g=g, rho_s=rho_s, rho_w=rho_w, option=47+1)
theta_prime_mag = np.sqrt(theta_prime_c**2+theta_prime_l**2)
theta_eff = theta_prime_mag -theta_crit
percexceed4 = (theta_eff>0).sum(dim='N')/len(ds.N)*100
q4 = 1e6*bedload_ribberink98(ds.rename({'ucm_nb':'ucm_nb2', 'ulm_nb':'ulm_nb2'}), d50=d50, option=47)
qp4 = np.sign(q4)*np.log(np.abs(q4)+1)

# %%
###############
#%% FIGURE 11
##############
def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = colors.LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

cmap = plt.get_cmap('CMRmap_r')
new_cmap = truncate_colormap(cmap, 0.2, 1.0)

# combined observed ripple pattern, and consistent yscales
fig, ax = plt.subplots(6, 2, figsize=[8,8], gridspec_kw={"width_ratios":[5, 1]})

# observed
ax[0, 0].plot(ds.t, ds.Tcross, c='k', marker='o', ms=2, linestyle='None', label='$ripples$')
ax[0, 0].set_ylabel('$Q_b\'_{ripple}$')

# total signal
im = ax[1, 0].scatter(ds.t, qp0, c=percexceed0, cmap=new_cmap, vmin=0, vmax=100, s=2)
plt.colorbar(im, label=r'% $\theta>\theta_{crit}$', ax=ax[0, 1], orientation='horizontal', location='top')
my_density_scatter(q0, ds.Tcross.values, ax[1, 1], loc='top')
ax[1, 0].set_ylabel('$Q_b\' (\\mathbf{u})$')

# # meanflow to nearbed
ax[2, 0].scatter(ds.t, qp1, c=percexceed1, cmap=new_cmap, vmin=0, vmax=100, s=2)
my_density_scatter(q1, ds.Tcross.values, ax[2, 1], loc='top')
ax[2, 0].set_ylabel('$Q_b\' (\\mathbf{u_{nb}})$')

# ig + seaswell
ax[3, 0].scatter(ds.t, qp5, c=percexceed5, cmap=new_cmap, vmin=0, vmax=100, s=2)
my_density_scatter(q5, ds.Tcross.values, ax[3, 1])
ax[3, 0].set_ylabel('$Q_b\'$\n $(\\mathbf{u}-\overline{u}_{CR})$')

# seaswell only
ax[4, 0].scatter(ds.t, qp3, c=percexceed3, cmap=new_cmap, vmin=0, vmax=100, s=2)
my_density_scatter(q3, ds.Tcross.values, ax[4, 1])
ax[4, 0].set_ylabel('$Q_b\'$\n $(\\mathbf{u}-\overline{u}_{CR}-{u_{cross,ig}})$')

# including downslope transport
ax[5, 0].scatter(ds.t, qp5+qpx_slope, c=percexceed5, cmap=new_cmap, vmin=0, vmax=100, s=2)
my_density_scatter(q5+qx_slope, ds.Tcross.values, ax[5, 1])
ax[5, 0].set_ylabel('$Q_b\'$\n $(\\mathbf{u}-\overline{u}_{CR})$ \n +$Q_{BG,n}\'$')

# add vertical lines for the peaks in the velocity signal
peaks, _ = find_peaks(np.abs(ds.ulm), distance=40)
peak_times = ds.t[peaks]
for peak in peak_times:
    ax[5, 0].axvline(peak.values, color='k', linewidth=0.5, linestyle='--')

ax[0, 1].axis('off')


plot_migrating_moments(ax[:, 0], alpha=0.1)
# formatting
for axi in ax[:, 0]:
    axi.set_xlim([ds.t.min(), ds.t.max()])
    axi.axhline(0, color='grey', linewidth=0.5, linestyle=':')
for axi in ax[:-1, 0]:
    axi.set_xticklabels([])
for axi in ax[1:-1, 1]:
    axi.set_xticklabels([]) 
for axi in ax[1:, 1]:
    axi.set_facecolor('lightgrey')
    axi.axhline(0, color='k', zorder=-2, linewidth=0.8)
    axi.axvline(0, color='k', zorder=-2, linewidth=0.8)
    axi.set_xlim([-3, 3])
for axi in ax.reshape(-1):
    axi.set_ylim([-3, 3])

ax[-1, 0].xaxis.set_major_formatter(DateFormatter('%m-%d'))
ax[-1, 1].set_xlabel('$Q_b$\'$_{ripple}$') 
ax[-1, 0].text(1, -0.3, 'mm-dd in 2023',transform = ax[-1, 0].transAxes, ha='right', va='top')

fig.align_ylabels()

# numbering of subpanels
import matplotlib.transforms as mtransforms
trans = mtransforms.ScaledTranslation(6 / 72, -5 / 72, fig.dpi_scale_trans)
for label, axi in zip(['a)', 'b)','c)', 'd)','e)', 'f)'], ax[:,0]):
    t = axi.text(0.92, 1.0, label, transform=axi.transAxes + trans,
            fontsize='large', verticalalignment='top')
    t.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='None'))
for label, axi in zip(['g)','h)', 'i)', 'j)', 'k)'], ax[1:,1]):
    t = axi.text(0.73, 0.33, label, transform=axi.transAxes + trans,
            fontsize='medium', verticalalignment='top')
    t.set_bbox(dict(facecolor='None', alpha=0.5, edgecolor='None'))

plt.savefig(os.path.join(plotFilePath, 'bed_load_transport.png'), dpi=200, bbox_inches='tight')
# Out:
# SignificanceResult(statistic=0.18823978498145658, pvalue=2.847024801536246e-06)
# SignificanceResult(statistic=0.26352800062512416, pvalue=3.777579353886661e-11)
# SignificanceResult(statistic=0.4035461237996347, pvalue=2.7077649015953305e-25)
# SignificanceResult(statistic=0.09371049440830378, pvalue=0.02062240185351505)
# SignificanceResult(statistic=0.2556805949689619, pvalue=1.467505649346792e-10)

# %%
# REBUTTAL FIGURE 
fig, ax = plt.subplots(1,2, figsize=[8,1], gridspec_kw={"width_ratios":[5, 1]})
ax[0].scatter(ds.t, qp4, c=percexceed4, cmap=new_cmap, vmin=0, vmax=100, s=2)
my_density_scatter(q4, ds.Tcross.values, ax[1], loc='top')
ax[0].set_ylabel('$Q_b\' (\overline{u}+\\vec{u_{ss}})$')

plot_migrating_moments(ax[0], alpha=0.1)

# formatting
ax[0].set_xlim([ds.t.min(), ds.t.max()])
ax[0].axhline(0, color='grey', linewidth=0.5, linestyle=':')
ax[1].set_facecolor('lightgrey')
ax[1].axhline(0, color='k', zorder=-2, linewidth=0.8)
ax[1].axvline(0, color='k', zorder=-2, linewidth=0.8)
ax[1].set_xlim([-3, 3])
for axi in ax:
    axi.set_ylim([-3, 3])

ax[0].xaxis.set_major_formatter(DateFormatter('%m-%d'))
ax[1].set_xlabel('$Q_b$\'$_{ripple}$') 
ax[0].text(1, -0.35, 'mm-dd in 2023',transform = ax[0].transAxes, ha='right', va='top')
# Out:
# SignificanceResult(statistic=0.3073888356131736, pvalue=8.15458794126689e-15)
# Text(1, -0.35, 'mm-dd in 2023')

# %%
# Evaluate the Sleath number during the observed migration events, and see how they compare to the values reported in the literature.

Sw = rho_s*(np.sqrt(2)*ds.u_ssm)*2*np.pi/ds.Tp/(rho_s-rho_w)/g
Sw.plot()
plt.axhline(0.37, c='green', label='Sleath 1999')
plt.axhline(0.29, c='r', label='Foster 2006')
plt.legend()
plt.ylabel('Sw [-]')
plt.title('Sleath number')
# Out:
# Text(0.5, 1.0, 'Sleath number')

# %%
# compare acceleration skewness with velocity asymmetry

fig, ax = plt.subplots(figsize=(10,3))
ax.plot(ds.t, ds.aspike, linewidth=3)
tax = ax.twinx()
tax.plot(ds.t, -ds.nAs, c='C1', linewidth=1)
tax.set_ylabel(r'$A_{u}$ [-]', c='C1')
ax.set_ylabel(r'$Sk(du/dt)$ [-]', c='C0')
tax.set_ylim([-0.2, 0.6])
ax.set_ylim([-0.2, 0.6])
ax.axhline(0, c='grey')
ax.set_title('')
tax.set_title('')
ax.xaxis.set_major_formatter(DateFormatter('%m-%d'))
plot_migrating_moments(ax)
ax.set_xlabel('')

print(spearman_stats(-ds.As/ds.sig**3, ds.aspike))
print(spearman_stats(-ds.As/ds.sig**3, ds.Sk/ds.sig**3))

# evaluate exceedance of acceleration spike compared to literature values
fig, ax = plt.subplots(figsize=[8, 3])
ds.aspike.plot()
plot_migrating_moments(ax)
plt.axhline(1, c='red', label='Drake and Calantoni (2001)')
plt.axhline(0.2, c='green', label='Hoefel and Elgar (2003)')
plt.legend()
plt.axhline(0, c='k', linewidth=0.5)
plt.ylabel('aspike [m/s$^2$]')

print('aspike_max={:.2f}'.format(ds.aspike.max()))
# Out:
# SignificanceResult(statistic=0.7761911897344241, pvalue=3.6974108259049644e-142)
# SignificanceResult(statistic=0.7695420145699836, pvalue=2.793095706181466e-138)
# aspike_max=0.54

# %%
# see the combined effect of all transport components, including the transverse bedload effect, on the observed ripple pattern.

fig, ax = plt.subplots(2, 1, figsize=[8, 3], sharex=True, gridspec_kw={'height_ratios': [3, 1]})
fig.subplots_adjust(hspace=0.08)
ax[0].plot(qpl5.t, qpl5, color='c', linestyle='--', label='alongshore transport', linewidth=0.7)
# plt.scatter(ds.t, qp5, c=percexceed5, cmap=new_cmap, vmin=0, vmax=100, s=2, label='hydro driven')
ax[0].plot(ds.t, qpx_slope, c='r', label='gravity driven cross-shore', linewidth=3)
ax[0].plot(ds.t, qp5+qpx_slope, label='total cross-shore', c='k', linewidth=2)
ax[0].plot(ds.t, qp5, label='shear-stress driven cross-shore', linewidth=1)

ax[0].axhline(0, c='k', linewidth=0.5)
ax[0].set_ylim([-3, 3])
ax[0].legend(ncol=2)
ax[0].set_ylabel('$Q\'_b (\\vec{u}-\overline{u}_{CR})$')

ax[1].plot(ds.t, np.abs(ds.ulm), c='k')
ax[1].set_ylabel('$|u_{along}|$ [m/s]')

plot_migrating_moments(ax)

for axi in ax:
    for peak in peak_times:
        axi.axvline(peak.values, color='k', linewidth=0.5, linestyle='--')
        
ax[-1].set_xlim([ds.t.min(), ds.t.max()])
ax[-1].xaxis.set_major_formatter(DateFormatter('%m-%d'))
ax[-1].text(1, -0.5, 'mm-dd in 2023',transform = ax[-1].transAxes, ha='right', va='top')

trans = mtransforms.ScaledTranslation(6 / 72, -5 / 72, fig.dpi_scale_trans)
for label, axi in zip(['a)', 'b)'], ax):
    t = axi.text(0., 1.0, label, transform=axi.transAxes + trans,
            fontsize='large', verticalalignment='top')
    t.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='None'))

plt.savefig(os.path.join(plotFilePath, 'transverse_bedslope.png'), dpi=200, bbox_inches='tight')

# %%
# Evaluate mean Shields values during moments of migration, and see how they compare to the critical Shields parameter.

migmoments = [['20231102 00:00', '20231102 02:30'],
['20231102 07:30', '20231102 10:00'],
['20231102 20:00', '20231103 00:30'],
['20231103 14:30', '20231103 17:45'],
['20231104 00:30', '20231104 02:15'],
['20231104 03:30', '20231104 08:00'],
['20231104 09:45', '20231104 13:15'],
['20231104 14:00', '20231104 15:30'],
['20231105 01:00', '20231105 07:30'],
['20231106 17:00', '20231106 20:00'],
['20231107 07:00', '20231107 08:00'],
['20231107 18:15', '20231107 21:00'],
['20231108 07:30', '20231108 10:30'],
['20231108 15:45', '20231108 18:00']]

Shields = theta_prime_mag.mean(dim='N')
shields_time = [pd.to_datetime(t[0])+(pd.to_datetime(t[1])-pd.to_datetime(t[0]))/2 for t in migmoments]

migmoment_meanshields=[]
migmoment_T=[]
for migmoment in migmoments:
    migmoment_meanshields.append(Shields.sel(t=slice(*migmoment)).mean(dim='t').values)
    migmoment_T.append(ds.Tcross_dimensional.sel(t=slice(*migmoment)).mean(dim='t').values)

migmoms = pd.DataFrame({"time":shields_time, "mean_transport":np.round(migmoment_T, 9), "mean_Shields": np.round(migmoment_meanshields, 3)})
print(migmoms)

fig, ax = plt.subplots(figsize=[10, 3])
plt.plot(shields_time, migmoment_meanshields, marker='o', linestyle='None')
plot_migrating_moments(ax)
plt.axhline(0.16, c='r')
plt.axhline(theta_crit, c='green')
plt.ylabel(r'$\theta$ [-]')
ax.xaxis.set_major_formatter(DateFormatter('%m-%d'))
# Out:
#                   time  mean_transport  mean_Shields
# 0  2023-11-02 01:15:00    5.620000e-07         0.081
# 1  2023-11-02 08:45:00   -2.180000e-07         0.139
# 2  2023-11-02 22:15:00   -4.250000e-07         0.093
# 3  2023-11-03 16:07:30    4.170000e-07         0.059
# 4  2023-11-04 01:22:30   -2.530000e-07         0.052
# 5  2023-11-04 05:45:00    3.280000e-07         0.107
# 6  2023-11-04 11:30:00   -5.600000e-07         0.052
# 7  2023-11-04 14:45:00    7.700000e-07         0.112
# 8  2023-11-05 04:15:00   -1.170000e-07         0.060
# 9  2023-11-06 18:30:00    3.300000e-08         0.027
# 10 2023-11-07 07:30:00    3.900000e-08         0.026
# 11 2023-11-07 19:37:30    8.300000e-08         0.026
# 12 2023-11-08 09:00:00    1.430000e-07         0.038
# 13 2023-11-08 16:52:30   -1.250000e-07         0.067

# %%
# Froude number
def fr(v,h):
    return v/np.sqrt(9.8*h)
plt.plot(ds.t, fr(ds.u_ssm, ds.h))

# %%
bicmfold = r'\\tudelft.net\staff-umbrella\EURECCA\01AnalyseRemote\data\bispectra\SEDRIB'

filez = glob.glob(bicmfold + r'\*.mat')
bicm_max = []
for file in filez:
    dat = sc.io.loadmat(file)
    bicm_max.append(np.max(dat['bicm'][:]))

numb = []
for file in filez:
    numb.append(int(file.split('\\')[-1].split('.')[0][5:]))
bicm_t = pd.to_datetime('20231101 18:00:00') + np.array(numb) * pd.Timedelta('1h')
ii = np.argsort(bicm_t)

filez = glob.glob(bicmfold + r'\*.mat')
bicm_all = []
for file in filez:
    dat = sc.io.loadmat(file)
    bicm_all.append(dat['bicm'])

fplist = ds.fp.coarsen(t=4, boundary='trim').mean()
frm = dat['frm'].flatten()
FX, FY = np.meshgrid(frm, frm)

bicm_max_III=[]
for i in range(len(bicm_all)):
    bicm_i = bicm_all[i]
    bicm_t_i = bicm_t[i]
    bicm_i_fp = fplist.sel(t=bicm_t_i, method='nearest').values
    masker = (FX>=bicm_i_fp/4)*(FY<=bicm_i_fp/4)*(FX>=0)*(FY>=0)
    bicm_max_III.append(np.max(np.where(masker, bicm_i, 0)))

dsbicm = pd.DataFrame({'t': bicm_t[ii], 'bicm_max': np.array(bicm_max)[ii]}).set_index('t').to_xarray()
dsbicm['h'] = ds.d.interp_like(dsbicm.t, method='nearest')
dsbicm['vmig'] = ds.vmig_cross_c.interp_like(dsbicm.t, method='nearest')

fig, ax = plt.subplots(1, 1, figsize=(10, 1.5))
# plt.plot(bicm_t[ii], np.array(bicm_max)[ii], marker='.', linestyle='None')
plt.plot(bicm_t[ii], np.sqrt(np.array(bicm_max_III))[ii], marker='.', linestyle='None')
plt.ylim(0, 1)
plt.axhline(0.14, c='k', linewidth=1)
plot_migrating_moments(ax)
ax.xaxis.set_major_formatter(DateFormatter('%m-%d'))
plt.ylabel('$b_{max, region\ III}$ [-]')
ax.text(1, -0.2, 'mm-dd in 2023',transform = ax.transAxes, ha='right', va='top')
